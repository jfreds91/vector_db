# %% [markdown]
# <a href="https://colab.research.google.com/github/jfreds91/vector_db/blob/main/jfdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !{sys.executable} -m pip install transformers pillow torch lmdb
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (10.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Collecting lmdb
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: lmdb
# Successfully installed lmdb-1.5.1

# %%
import torch
from PIL import Image
import requests

from transformers import CLIPProcessor, CLIPModel

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

inputs = processor(text=["a photo of a cat", "a photo of a dog"], images=image, return_tensors="pt", padding=True)

with torch.no_grad():
  outputs = model(**inputs)

logits_per_image = outputs.logits_per_image  # this is the image-text similarity score
probs = logits_per_image.softmax(dim=1)  # we can take the softmax to get the label probabilities

# The embeddings for text and images are in outputs.text_embeds and outputs.image_embeds respectively
text_embeddings = outputs.text_embeds
image_embeddings = outputs.image_embeds

# Normalize the embeddings if needed
text_embeddings_norm = text_embeddings / text_embeddings.norm(dim=-1, keepdim=True)
image_embeddings_norm = image_embeddings / image_embeddings.norm(dim=-1, keepdim=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
print(text_embeddings)
# Out:
# tensor([[ 0.0148,  0.0070, -0.0234,  ..., -0.0508, -0.0438,  0.0033],
#         [ 0.0087,  0.0258, -0.0387,  ..., -0.0547, -0.0242,  0.0112]])

# %%
text_embeddings[0].shape
# Out:
# torch.Size([512])

# %%
image_embeddings[0].shape
# Out:
# torch.Size([512])

# %%
# dot product is affected by magnitude. Returns unbounded measurement
dot_product = torch.sum(text_embeddings[0] * image_embeddings[0], dim=-1)
dot_product
# Out:
# tensor(0.2457)

# %%
# cosine is not affected by magnitude. [-1, 1]
cosine_similarity = torch.nn.functional.cosine_similarity(text_embeddings_norm[0], image_embeddings_norm[0], dim=0)
cosine_similarity
# Out:
# tensor(0.2457)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
image.size
# Out:
# (640, 480)

# %%
logits_per_image
# Out:
# tensor([[24.5701, 19.3049]])

# %%
url = "https://www.pokemon.com/static-assets/content-assets/cms2/img/pokedex/full/025.png"

def get_image_from_url(url:str):
  return Image.open(requests.get(url, stream=True).raw)

def get_embedding_from_image(image:Image.Image, processor, model):
  im_input = processor(images=image, return_tensors="pt", padding=True)
  with torch.no_grad():
    image_embeddings = model.get_image_features(**im_input)
  return image_embeddings

image = get_image_from_url(url)
image_embeddings = get_embedding_from_image(image, processor, model)


texts = ['yellow rat', 'pikachu', 'cat', 'dog', 'electric mouse', 'yellow dog']
text_input = processor(text=texts, return_tensors="pt", padding=True)

with torch.no_grad():
  text_embeddings = model.get_text_features(**text_input)

for t, vec in zip(texts, text_embeddings):
  print(f'{t}: {torch.sum(vec * image_embeddings[0], dim=-1)}')
# Out:
# yellow rat: 25.58464813232422
# pikachu: 29.851242065429688
# cat: 24.02277946472168
# dog: 26.806631088256836
# electric mouse: 25.678815841674805
# yellow dog: 23.994962692260742

# %%
pikachu = text_embeddings[1]

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=475x475>

# %%
import heapq

class MaxHeap:
    def __init__(self):
        self._heap = []

    def push(self, priority, obj):
        # Use negative priority to simulate a max heap with heapq (which is a min heap by default)
        heapq.heappush(self._heap, (-priority, obj))

    def pop(self):
        # Extract the item with the maximum priority (inverting the priority back)
        priority, obj = heapq.heappop(self._heap)
        return -priority, obj

    def peek(self):
        # Peek at the maximum priority item without popping it
        if self._heap:
            priority, obj = self._heap[0]
            return -priority, obj
        return None

    def peek_priority(self):
        # Peek at the maximum priority item without popping it
        if self._heap:
            priority, _ = self._heap[0]
            return -priority
        return None

    def __len__(self):
        # Return the number of items in the heap
        return len(self._heap)

    def dump_to_list(self):
        # Dump all elements in the heap to a list, ordered by priority (max to min)
        result_obj = []
        result_priority = []
        while self._heap:
            priority, obj = self.pop()
            result_obj.append(obj)
            result_priority.append(priority)
        return result_obj, result_priority

# %%
from __future__ import annotations  # allows forward reference
from typing import Iterable
from collections import defaultdict
from typing import Optional, List, Dict
import math
import pickle
import random
import logging
from importlib import reload
reload(logging)
logging.basicConfig(level=logging.DEBUG)

class Node():

  def __init__(self, id, layers:int, embedding:Optional[Iterable]=None, filepath:Optional[str]=None,):
    '''
    Layer edges is the key of another Node, not the node object itself
    '''
    self.id=id
    self.embedding = embedding
    self.layers = layers
    self.filepath = filepath
    self.layer_edges:Dict[int, List[Union[str, bytes]]] = defaultdict(list)

  @property
  def byte_id(self):
    return self.id.encode('utf-8')

  @property
  def key(self):
    return self.byte_id

  def __repr__(self):
    return self.id

  def add_edge(self, layer:int, node:Node, _recurse:bool=True):

    assert type(node)==Node

    logging.debug(f'adding {node.key} to {self} in layer {layer}')
    if node.key not in self.layer_edges[layer]:
      self.layer_edges[layer].append(node.key)
    else:
      raise KeyError(f"{self.id} already has an edge to {node.key}!")
    if _recurse:
      node.add_edge(layer=layer, node=self, _recurse=False)

  def get_edges(self, layer) -> Union[bytes, str]:
      keys = self.layer_edges[layer]
      assert all([type(key)==bytes for key in keys])
      return keys

  def __lt__(self, other):
    if isinstance(other, Node):
      return self.id < other.id
    raise NotImplementedError(f'Node.__lt__() is undefined for {type(other)}')

  def __eq__(self, other):
    # Define equality based on unique attributes (e.g., id)
    if isinstance(other, Node):
        return self.id == other.id
    return False

  def __hash__(self):
      # Combine the hashes of attributes to ensure a unique and consistent hash
      return hash(self.id)

  def __gt__(self, other):
    logging.warning(f'Someone just tried to compare nodes {self} > {other}')

  def serialize(self) -> bytes:
    return pickle.dumps(self)

  @classmethod
  def deserialize(cls, serialized_node:bytes) -> Node:
    return pickle.loads(serialized_node)

# Create a Node instance
no = Node('a', 3)
node2 = Node('b', 3)

# Add edges to the various lists
no.add_edge(0, node2)
print(no.get_edges(0))
# Out:
# DEBUG:root:adding b'b' to a in layer 0
# DEBUG:root:adding b'a' to b in layer 0
# [b'b']

# %%
from abc import ABC, abstractmethod
import lmdb
import warnings
from typing import Union, Type

class Backend(ABC):

  def __init__(self, name:Optional[str]="default_db", node_type:Type[Node]=Node):
    self.name = name
    self.node_type = node_type

  @abstractmethod
  def init_backend(self):
    pass

  @abstractmethod
  def drop_backend(self):
    pass

  @abstractmethod
  def write_node(self, node:Node):
    pass

  @abstractmethod
  def read_node(self, id:Union[str, bytes]) -> Node:
    pass

  @abstractmethod
  def get_percent_full(self) -> float:
    pass


class LMDBBackend(Backend):

  def __init__(self, *args, preallocated_bytes:int=int(1e6), **kwargs):
    super().__init__(*args, **kwargs)
    self.env = None
    self.preallocated_bytes = preallocated_bytes

    # Ignore FutureWarning: torch.load should have weights_only=True to prevent arbitrary code execution
    warnings.simplefilter(action='ignore', category=FutureWarning)

  def init_backend(self):
    # Create an LMDB environment
    self.env = lmdb.open(self.name, map_size=self.preallocated_bytes)
    logging.info(f'Initialized {self.env.path()}')

    # TODO: if backend exists but a user specified a different preallocated bytes, fail loudly

  def drop_backend(self):
    if self.env is None:
      self.init_backend()
      # raise RuntimeError('Cannot drop backend if it has not been initialized. Run init_backend first')

    # Begin a write transaction to clear the database
    with self.env.begin(write=True) as txn:
      txn.drop(db=self.env.open_db(), delete=False)

    # Optionally: Sync and close
    self.env.sync()
    self.env.close()

  def write_node(self, node:Node):
    # Storing the Node object in LMDB using pickle
    with self.env.begin(write=True) as txn:
      txn.put(node.key, node.serialize())  # Store in LMDB
    logging.debug(f'Wrote key {node.key} to {self.env.path()}')

  def read_node(self, key:Union[str, bytes]) -> Node:
    # Retrieving the Node object from LMDB
    with self.env.begin() as txn:
      serialized_node = txn.get(key)  # Retrieve serialized data
      if serialized_node:
        logging.debug(f'Got serialized Node: {serialized_node}')
        node = self.node_type.deserialize(serialized_node)
        logging.debug(f'Read key {node.key} from {self.env.path()}')
        return node
    return None

  def get_percent_full(self) -> float:
    '''
    return value is between 0 and 1
    '''
    # Get the current map size (allocated size)
    map_size = self.env.info()['map_size']

    # Get the size of the data currently in the database
    used_size = self.env.stat()['psize'] * self.env.stat()['leaf_pages']

    # Calculate percentage usage
    return used_size / map_size

# # test
# test_backend = LMDBBackend(name='testdb', preallocated_bytes=1000)
# test_backend.drop_backend()

# %%
from collections import deque
from dataclasses import dataclass

@dataclass
class BFSResult:
  nodes: List[Node]
  priorities: List[float]
  total_traversed_nodes: int

def bfs_with_max_heap(search_node:Node, start_nodes:List[Node], ef:int, layer:int, backend:Backend, multi_hop:bool=False) -> BFSResult:
  logging.debug(f'Starting bfs on layer {layer} with {len(start_nodes)} start nodes: {[sn.id for sn in start_nodes]}, ef {ef}...')

  _total_traversed_nodes = 0
  max_heap = MaxHeap()
  stacked_tensors = torch.stack([i.embedding for i in start_nodes])
  dot_products = torch.sum(search_node.embedding * stacked_tensors, dim=-1).tolist()

  for priority, node in zip(dot_products, start_nodes):
    max_heap.push(priority, node)
    _total_traversed_nodes += 1

  if len(max_heap) >= ef and multi_hop is False:
    logging.debug(f'\tReached ef using search nodes only, returning early')
    while len(max_heap) > ef:
      max_heap.pop()
    objs, prios = max_heap.dump_to_list()
    return BFSResult(nodes=objs, priorities=prios, total_traversed_nodes=_total_traversed_nodes)

  # Queue for BFS
  queue = deque(start_nodes)
  # Set to track visited nodes
  visited = set(start_nodes)

  while queue:
    current_node = queue.popleft()
    assert type(current_node) == Node
    candidate_keys = current_node.get_edges(layer)
    try:
      types = [type(i) for i in candidate_keys]
      assert all([i==bytes for i in types])
    except AssertionError as e:
      raise AssertionError(f'BFS got bad keys: {candidate_keys} with types: {types}')

    # load from backend
    candidates = [backend.read_node(key) for key in candidate_keys]
    try:
      types = [type(i) for i in candidates]
      assert all([i==Node for i in types])
    except AssertionError as e:
      raise AssertionError(f'BFS got bad candidates: {candidates} with types: {types}')

    # prune any returned neighbors that we've already explored
    candidates = list(set(candidates).difference(visited))  # TODO: should both of these be lists of nodes or keys?
    logging.debug(f'\tGot {len(candidates)} unexplored neighbors from node {current_node.id}: {[c.id for c in candidates]}')

    if len(candidates) > 0:
      stacked_tensors = torch.stack([i.embedding for i in candidates])
      dot_products = torch.sum(search_node.embedding * stacked_tensors, dim=-1).tolist()
      for prio, node in zip(dot_products, candidates):
        _total_traversed_nodes += 1

        if len(max_heap) == ef:
          # only add to heap if it is better than the current worst
          if prio > max_heap.peek_priority():
            max_heap.pop()
            max_heap.push(prio, node)
            queue.append(node)
            visited.add(node)
        else:
          # append and search neighbors too
          max_heap.push(prio, node)
          queue.append(node)
          visited.add(node)
  objs, prios = max_heap.dump_to_list()
  logging.debug(f"priorities found by bfs {[round(d, 2) for d in prios]}")

  # TODO: consider unloading all unused nodes from memory
  return BFSResult(nodes=objs, priorities=prios, total_traversed_nodes=_total_traversed_nodes)

# %%
import numpy as np

class DataBase():
  # https://www.pinecone.io/learn/series/faiss/hnsw/
  def __init__(
      self,
      L:int,
      M:int,
      ef_construction:int,
      d:int,
      m_L:Optional[float]=None,
      M_max:Optional[int]=None,
      M_max0:Optional[int]=None,
      ef:int=1,
      backend:Optional[Backend]=None,
      node_type:Type[Node]=Node
    ):
    '''
    Convention is that layer 0 is the base layer

    L: number of layers total
    m_L: level multiplier. Normalization function on top of layer insertion probability function.
      m_L=0 means vectors are only inserted at layer 0. A rule of thumb is to set it at m_L=1/ln(M)
    M: number of connections to make per inserted vertex
    M_max: max number of allowable edges per vertex
    M_max0: max number of allowable edges per vertex in layer 0 only
    ef_construction: number of nearest neighbors to return as edge candidates after insertion layer
    d: dimensionality of vectors
    ef: number of nearest neighbors to return before insertion
    '''
    self.L = L
    self.M = M
    self.m_L = m_L or 1/math.log(M)
    self.M_max = M_max or M
    self.M_max0 = M_max0 or M*2
    self.ef_construction = ef_construction
    self.ef = ef
    self.d = d
    self.node_type = node_type

    self.model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
    self.processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
    self.backend = backend or LMDBBackend(
        name="default_db",
        preallocated_bytes=int(1e7),
        node_type=self.node_type,
      )
    self.backend.init_backend()

    # self.entry_layer = []
    self.dense_layer = []
    self.layers = {i:[] for i in range(self.L)}  # DEBUGGING


  @property
  def entry_layer(self):
    return self.L-1

  def insert(self, node:Node, insertion_layer:Optional[int]=None):
    if self.backend.env.stat()['entries'] > 0:
      if self.backend.read_node(node.key) is not None:
        raise IndexError(f'a key of {node.key} already exists in the backend')

    _total_traversed_nodes = 0

    if insertion_layer is None:
      insertion_layer = 0
      if len(self.layers[self.entry_layer]) == 0:
        # this is our first input, always insert into entry layer
        insertion_layer = self.entry_layer
      else:
        # uniform random insertion probability threshold
        insertion_thresh = random.uniform(0, 1)
        for i in reversed(range(self.L)):
          prob = self.probability_function(i)
          if prob > insertion_thresh:
            insertion_layer = i
            break
          else:
            insertion_thresh -= prob  # FAISS does this so so will I
    logging.debug(f'Determined insertion_layer: {insertion_layer}')

    # Graph construction starts at the top layer.
    try:
      candidate_node_keys = [random.choice(self.layers[self.entry_layer])]
      _total_traversed_nodes += 1
    except IndexError:
      # no entry node found - means this is our first insertion
      candidate_node_keys = []

    # Phase 1
    # ----------------
    current_layer = self.entry_layer

    # load from backend. Only have to do this for entry since bfs loads them the rest of the time
    candidate_nodes = [self.backend.read_node(key) for key in candidate_node_keys]

    while current_layer > insertion_layer:
      logging.debug(f'P1: current_layer: {current_layer}')
      # After entering the graph the algorithm greedily traverse across edges,
      #  finding the ef nearest neighbors to our inserted vector q — at this point ef = 1.
      bfs_results = bfs_with_max_heap(
        search_node=node,
        start_nodes=candidate_nodes,
        ef=1,
        layer=current_layer,
        backend=self.backend,
      )
      _total_traversed_nodes += bfs_results.total_traversed_nodes - len(candidate_nodes)  # dont double count the candidate nodes
      candidate_nodes = bfs_results.nodes
      current_layer -= 1
      logging.debug(f'P1: updated search node to {candidate_nodes[0].id}')

      # This process is repeated until reaching our chosen insertion layer

    # Phase 2
    # ----------------
    # The ef value is increased to efConstruction (a parameter we set), meaning more nearest neighbors will be returned.
    # In phase two, these nearest neighbors are candidates for the links to the new inserted element q and as entry points to the next layer.

    while current_layer >= 0:
      logging.debug(f'P2: current_layer: {current_layer}')
      self.layers[current_layer].append(node.key)  # debugging
      if len(candidate_nodes) == 0:
        # nothing to seed our search - will happen on first insertion
        logging.debug(f'P2: Got 0 candidate nodes')
        pass
      else:
        bfs_results = bfs_with_max_heap(
          search_node=node,
          start_nodes=candidate_nodes,
          ef=self.ef_construction,
          layer=current_layer,
          backend=self.backend,
        )
        _total_traversed_nodes += bfs_results.total_traversed_nodes - len(candidate_nodes)  # dont double count the candidate nodes
        candidate_nodes = bfs_results.nodes
        logging.debug(f'P2: Got {len(candidate_nodes)} candidate nodes')

        # M neighbors are added as links from these candidates — the most straightforward selection criteria are to choose the closest vectors.
        for i, n in enumerate(reversed(candidate_nodes[-self.M:])):
          logging.debug(f'P2 Adding edge to {n.id}')
          node.add_edge(current_layer, n)  # no need to load since these nodes were necessarily loaded by bfs already
          self.backend.write_node(n)  # but we do need to write them to the backend now that they have edges
      current_layer -= 1

      # TODO: implement
      # After working through multiple iterations, there are two more parameters that are considered when adding links.
      # M_max, which defines the maximum number of links a vertex can have,
      # and M_max0, which defines the same but for vertices in layer 0.

    # persist node
    self.backend.write_node(node)
    logging.info(f'Inserted {node}')
    logging.debug(f'Traversed {_total_traversed_nodes} during insertion')
    return

  def delete(self, node:Node):
    # TODO: implement
    pass

  def search(self, text:Optional[str]=None, image:Optional[Image.Image]=None) -> Node:
    # TODO: what if we want to return top k results?

    embedding = None
    if text is not None and image is not None:
      raise ValueError('Only one of text, image should be provided for search')

    if text is not None:
      # get embedding from text
      text_input = self.processor(text=[text], return_tensors="pt", padding=True)
      with torch.no_grad():
        embedding = self.model.get_text_features(**text_input)[0]  # take first index since this is batched

    elif image is not None:
      # get embedding from image
      im_input = self.processor(images=image, return_tensors="pt", padding=True)
      with torch.no_grad():
        embeddings = self.model.get_image_features(**im_input)
    else:
      raise ValueError('text and image cannot both be None')
    return self.search_embedding(embedding)

  def search_embedding(self, embedding:Iterable) -> Node:
    # similar to insertion
    _total_traversed_nodes = 0

    dummy_node = Node(
        id='tmp',
        layers=self.L,
        embedding=embedding
    )  # TODO: making a dummy node feels like a design flaw

    current_layer = self.entry_layer
    candidate_node_keys = [random.choice(self.layers[current_layer])]
    _total_traversed_nodes += 1

    # load from backend. Only have to do this for entry since bfs loads them the rest of the time
    candidate_nodes = [self.backend.read_node(key) for key in candidate_node_keys]

    while current_layer >= 0:
      logging.debug(f'current_layer: {current_layer}')
      bfs_results = bfs_with_max_heap(
        search_node=dummy_node,
        start_nodes=candidate_nodes,
        ef=1,
        layer=current_layer,
        backend=self.backend,
        multi_hop=True
      )
      _total_traversed_nodes += bfs_results.total_traversed_nodes - len(candidate_nodes)
      candidate_nodes = bfs_results.nodes
      current_layer -= 1

    logging.debug(f'Traversed {_total_traversed_nodes} during search')
    return bfs_results.nodes[0], bfs_results.priorities[0]

  def probability_function(self, layer:int):
    '''
    Probability of insertion at each layer
    '''
    return np.exp(-layer / self.m_L) * (1 - np.exp(-1 / self.m_L))

  def search_brute_force(self, embedding):
    pass

# %%
# prompt: delete a local folder "default_db" and all its contents

# !rm -rf default_db

# %%
reload(logging)
logging.basicConfig(
    format='%(name)s:%(levelname)s:%(funcName)s: %(message)s',
    level=logging.DEBUG
)

db = DataBase(
    L=4,
    M=10,
    # m_L=1,  # increase to 1 to force more edges
    d=512,
    M_max=10,
    M_max0=20,
    ef_construction=10,
    # backend=LMDBBackend(
    #     name="another_db",
    #     preallocated_bytes=int(1e6),
    #     node_type=Node,
    #   )
)
# Out:
# root:INFO:init_backend: Initialized default_db

# %%
# probability of insertion at each layer?
for i in range(db.L):
  print(db.probability_function(i))
# Out:
# 0.9
# 0.08999999999999998
# 0.008999999999999996
# 0.0008999999999999994

# %%
def get_image_from_url(url:str):
  return Image.open(requests.get(url, stream=True).raw)

def get_embedding_from_image(image:Image.Image, processor, model):
  im_input = processor(images=image, return_tensors="pt", padding=True)
  with torch.no_grad():
    image_embeddings = model.get_image_features(**im_input)
  return image_embeddings

# image = get_image_from_url(url)
# image_embeddings = get_embedding_from_image(image, db.processor, db.model)

# node = Node(
#   id='pikachu',
#   layers=db.L,  # seems like there's on reason I should need to put this in here
#   embedding=image_embeddings[0]
# )

# %%
# prompt: given a folder on my google drive, iteratively load the image files within

reload(logging)
logging.basicConfig(
    format='%(name)s:%(levelname)s:%(funcName)s: %(message)s',
    # level=logging.DEBUG
    level=logging.INFO
)

import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Specify the folder path
folder_path = '/content/drive/My Drive/Pokemon Dataset'  # Replace with your folder name

# Iterate over files in the folder
for filename in os.listdir(folder_path):
  if filename.endswith(('.jpg', '.jpeg', '.png')):  # Check for image files
    file_path = os.path.join(folder_path, filename)
    # try:
    image = Image.open(file_path)
    # Process the image here (e.g., get embedding)
    image_embeddings = get_embedding_from_image(image, db.processor, db.model)
    node = Node(
        id=filename.split('.')[0],
        layers=db.L,  # TODO: we shouldn't need this
        embedding=image_embeddings[0],
        filepath=filename
    )
    db.insert(node)
    #   print(f'Processed image: {filename}')
    # except Exception as e:
    #   print(f'Error processing image {filename}: {e}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# root:INFO:insert: Inserted bergmite
# root:INFO:insert: Inserted barboach
# root:INFO:insert: Inserted alakazam
# root:INFO:insert: Inserted azelf
# root:INFO:insert: Inserted axew
# root:INFO:insert: Inserted braixen
# root:INFO:insert: Inserted celebi
# root:INFO:insert: Inserted carracosta
# root:INFO:insert: Inserted arceus-normal
# root:INFO:insert: Inserted chandelure
# root:INFO:insert: Inserted blacephalon
# root:INFO:insert: Inserted braviary
# root:INFO:insert: Inserted arrokuda
# root:INFO:insert: Inserted banette
# root:INFO:insert: Inserted arbok
# root:INFO:insert: Inserted butterfree
# root:INFO:insert: Inserted blaziken
# root:INFO:insert: Inserted bouffalant
# root:INFO:insert: Inserted burmy-plant
# root:INFO:insert: Inserted aromatisse
# root:INFO:insert: Inserted araquanid
# root:INFO:insert: Inserted articuno
# root:INFO:insert: Inserted charmander
# root:INFO:insert: Inserted binacle
# root:INFO:insert: Inserted carbink
# root:INFO:insert: Inserted charjabug
# root:INFO:insert: Inserted abomasnow
# root:INFO:insert: Inserted armaldo
# root:INFO:insert: Inserted castform
# root:INFO:insert: Inserted calyrex
# root:INFO:insert: Inserted aerodactyl
# root:INFO:insert: Inserted bastiodon
# root:INFO:insert: Inserted brionne
# root:INFO:insert: Inserted altaria
# root:INFO:insert: Inserted blipbug
# root:INFO:insert: Inserted arcanine
# root:INFO:insert: Inserted boltund
# root:INFO:insert: Inserted celesteela
# root:INFO:insert: Inserted centiskorch
# root:INFO:insert: Inserted cascoon
# root:INFO:insert: Inserted bellsprout
# root:INFO:insert: Inserted accelgor
# root:INFO:insert: Inserted bayleef
# root:INFO:insert: Inserted basculin-red-striped
# root:INFO:insert: Inserted bagon
# root:INFO:insert: Inserted beedrill
# root:INFO:insert: Inserted bonsly
# root:INFO:insert: Inserted arctovish
# root:INFO:insert: Inserted alomomola
# root:INFO:insert: Inserted aron
# root:INFO:insert: Inserted bellossom
# root:INFO:insert: Inserted charizard
# root:INFO:insert: Inserted breloom
# root:INFO:insert: Inserted blastoise
# root:INFO:insert: Inserted aurorus
# root:INFO:insert: Inserted blitzle
# root:INFO:insert: Inserted buneary
# root:INFO:insert: Inserted blissey
# root:INFO:insert: Inserted beldum
# root:INFO:insert: Inserted archen
# root:INFO:insert: Inserted amoonguss
# root:INFO:insert: Inserted absol
# root:INFO:insert: Inserted boldore
# root:INFO:insert: Inserted beautifly
# root:INFO:insert: Inserted carvanha
# root:INFO:insert: Inserted bruxish
# root:INFO:insert: Inserted bisharp
# root:INFO:insert: Inserted bewear
# root:INFO:insert: Inserted camerupt
# root:INFO:insert: Inserted abra
# root:INFO:insert: Inserted bronzor
# root:INFO:insert: Inserted cacnea
# root:INFO:insert: Inserted audino
# root:INFO:insert: Inserted barraskewda
# root:INFO:insert: Inserted bounsweet
# root:INFO:insert: Inserted arctozolt
# root:INFO:insert: Inserted amaura
# root:INFO:insert: Inserted bibarel
# root:INFO:insert: Inserted carnivine
# root:INFO:insert: Inserted barbaracle
# root:INFO:insert: Inserted avalugg
# root:INFO:insert: Inserted aipom
# root:INFO:insert: Inserted buizel
# root:INFO:insert: Inserted beartic
# root:INFO:insert: Inserted beheeyem
# root:INFO:insert: Inserted alcremie
# root:INFO:insert: Inserted bidoof
# root:INFO:insert: Inserted azumarill
# root:INFO:insert: Inserted azurill
# root:INFO:insert: Inserted caterpie
# root:INFO:insert: Inserted ampharos
# root:INFO:insert: Inserted bulbasaur
# root:INFO:insert: Inserted buzzwole
# root:INFO:insert: Inserted baltoy
# root:INFO:insert: Inserted chansey
# root:INFO:insert: Inserted anorith
# root:INFO:insert: Inserted carkol
# root:INFO:insert: Inserted archeops
# root:INFO:insert: Inserted applin
# root:INFO:insert: Inserted cacturne
# root:INFO:insert: Inserted aggron
# root:INFO:insert: Inserted appletun
# root:INFO:insert: Inserted ariados
# root:INFO:insert: Inserted budew
# root:INFO:insert: Inserted aegislash-shield
# root:INFO:insert: Inserted ambipom
# root:INFO:insert: Inserted bunnelby
# root:INFO:insert: Inserted bronzong
# root:INFO:insert: Inserted eevee
# root:INFO:insert: Inserted feebas
# root:INFO:insert: Inserted fletchinder
# root:INFO:insert: Inserted cosmog
# root:INFO:insert: Inserted coalossal
# root:INFO:insert: Inserted dusknoir
# root:INFO:insert: Inserted clefable
# root:INFO:insert: Inserted chikorita
# root:INFO:insert: Inserted darkrai
# root:INFO:insert: Inserted dhelmise
# root:INFO:insert: Inserted clefairy
# root:INFO:insert: Inserted drednaw
# root:INFO:insert: Inserted empoleon
# root:INFO:insert: Inserted cresselia
# root:INFO:insert: Inserted clamperl
# root:INFO:insert: Inserted drakloak
# root:INFO:insert: Inserted darumaka
# root:INFO:insert: Inserted drowzee
# root:INFO:insert: Inserted cinderace
# root:INFO:insert: Inserted dragonair
# root:INFO:insert: Inserted flapple
# root:INFO:insert: Inserted delibird
# root:INFO:insert: Inserted dunsparce
# root:INFO:insert: Inserted gligar
# root:INFO:insert: Inserted chimecho
# root:INFO:insert: Inserted golbat
# root:INFO:insert: Inserted dragalge
# root:INFO:insert: Inserted garchomp
# root:INFO:insert: Inserted deino
# root:INFO:insert: Inserted garbodor
# root:INFO:insert: Inserted gastly
# root:INFO:insert: Inserted dusclops
# root:INFO:insert: Inserted goodra
# root:INFO:insert: Inserted combee
# root:INFO:insert: Inserted espurr
# root:INFO:insert: Inserted eelektross
# root:INFO:insert: Inserted fearow
# root:INFO:insert: Inserted cranidos
# root:INFO:insert: Inserted gothorita
# root:INFO:insert: Inserted crabominable
# root:INFO:insert: Inserted giratina-altered
# root:INFO:insert: Inserted foongus
# root:INFO:insert: Inserted corvisquire
# root:INFO:insert: Inserted comfey
# root:INFO:insert: Inserted goldeen
# root:INFO:insert: Inserted golduck
# root:INFO:insert: Inserted eiscue-ice
# root:INFO:insert: Inserted eternatus
# root:INFO:insert: Inserted flabebe-red
# root:INFO:insert: Inserted copperajah
# root:INFO:insert: Inserted electabuzz
# root:INFO:insert: Inserted cradily
# root:INFO:insert: Inserted electivire
# root:INFO:insert: Inserted ditto
# root:INFO:insert: Inserted dottler
# root:INFO:insert: Inserted excadrill
# root:INFO:insert: Inserted gliscor
# root:INFO:insert: Inserted cofagrigus
# root:INFO:insert: Inserted dodrio
# root:INFO:insert: Inserted glastrier
# root:INFO:insert: Inserted floatzel
# root:INFO:insert: Inserted galvantula
# root:INFO:insert: Inserted gourgeist-average
# root:INFO:insert: Inserted furfrou-natural
# root:INFO:insert: Inserted clawitzer
# root:INFO:insert: Inserted ducklett
# root:INFO:insert: Inserted chingling
# root:INFO:insert: Inserted flaaffy
# root:INFO:insert: Inserted gardevoir
# root:INFO:insert: Inserted clauncher
# root:INFO:insert: Inserted dragapult
# root:INFO:insert: Inserted drilbur
# root:INFO:insert: Inserted druddigon
# root:INFO:insert: Inserted decidueye
# root:INFO:insert: Inserted cherrim-overcast
# root:INFO:insert: Inserted golem
# root:INFO:insert: Inserted espeon
# root:INFO:insert: Inserted frillish
# root:INFO:insert: Inserted duosion
# root:INFO:insert: Inserted gengar
# root:INFO:insert: Inserted ferroseed
# root:INFO:insert: Inserted drapion
# root:INFO:insert: Inserted corsola
# root:INFO:insert: Inserted golett
# root:INFO:insert: Inserted chimchar
# root:INFO:insert: Inserted cryogonal
# root:INFO:insert: Inserted dreepy
# root:INFO:insert: Inserted falinks
# root:INFO:insert: Inserted delcatty
# root:INFO:insert: Inserted cubchoo
# root:INFO:insert: Inserted cubone
# root:INFO:insert: Inserted dewgong
# root:INFO:insert: Inserted combusken
# root:INFO:insert: Inserted gogoat
# root:INFO:insert: Inserted electrike
# root:INFO:insert: Inserted elekid
# root:INFO:insert: Inserted dratini
# root:INFO:insert: Inserted croconaw
# root:INFO:insert: Inserted gigalith
# root:INFO:insert: Inserted dartrix
# root:INFO:insert: Inserted frosmoth
# root:INFO:insert: Inserted granbull
# root:INFO:insert: Inserted fomantis
# root:INFO:insert: Inserted cloyster
# root:INFO:insert: Inserted chinchou
# root:INFO:insert: Inserted farfetchd
# root:INFO:insert: Inserted cleffa
# root:INFO:insert: Inserted croagunk
# root:INFO:insert: Inserted flygon
# root:INFO:insert: Inserted cottonee
# root:INFO:insert: Inserted escavalier
# root:INFO:insert: Inserted genesect
# root:INFO:insert: Inserted doduo
# root:INFO:insert: Inserted fennekin
# root:INFO:insert: Inserted deerling-spring
# root:INFO:insert: Inserted drifloon
# root:INFO:insert: Inserted donphan
# root:INFO:insert: Inserted diancie
# root:INFO:insert: Inserted cobalion
# root:INFO:insert: Inserted eldegoss
# root:INFO:insert: Inserted frogadier
# root:INFO:insert: Inserted cyndaquil
# root:INFO:insert: Inserted crustle
# root:INFO:insert: Inserted cosmoem
# root:INFO:insert: Inserted chespin
# root:INFO:insert: Inserted gastrodon-west
# root:INFO:insert: Inserted drampa
# root:INFO:insert: Inserted girafarig
# root:INFO:insert: Inserted duskull
# root:INFO:insert: Inserted emboar
# root:INFO:insert: Inserted glameow
# root:INFO:insert: Inserted entei
# root:INFO:insert: Inserted ekans
# root:INFO:insert: Inserted froakie
# root:INFO:insert: Inserted ferrothorn
# root:INFO:insert: Inserted cufant
# root:INFO:insert: Inserted dewpider
# root:INFO:insert: Inserted dewott
# root:INFO:insert: Inserted dubwool
# root:INFO:insert: Inserted elgyem
# root:INFO:insert: Inserted drizzile
# root:INFO:insert: Inserted exploud
# root:INFO:insert: Inserted furret
# root:INFO:insert: Inserted drifblim
# root:INFO:insert: Inserted delphox
# root:INFO:insert: Inserted gothitelle
# root:INFO:insert: Inserted cinccino
# root:INFO:insert: Inserted gloom
# root:INFO:insert: Inserted diggersby
# root:INFO:insert: Inserted froslass
# root:INFO:insert: Inserted cursola
# root:INFO:insert: Inserted cherubi
# root:INFO:insert: Inserted gothita
# root:INFO:insert: Inserted darmanitan-standard
# root:INFO:insert: Inserted florges-red
# root:INFO:insert: Inserted finneon
# root:INFO:insert: Inserted gorebyss
# root:INFO:insert: Inserted dustox
# root:INFO:insert: Inserted gossifleur
# root:INFO:insert: Inserted corphish
# root:INFO:insert: Inserted cutiefly
# root:INFO:insert: Inserted feraligatr
# root:INFO:insert: Inserted eelektrik
# root:INFO:insert: Inserted chesnaught
# root:INFO:insert: Inserted cramorant
# root:INFO:insert: Inserted corviknight
# root:INFO:insert: Inserted electrode
# root:INFO:insert: Inserted golurk
# root:INFO:insert: Inserted dragonite
# root:INFO:insert: Inserted crabrawler
# root:INFO:insert: Inserted emolga
# root:INFO:insert: Inserted charmeleon
# root:INFO:insert: Inserted diglett
# root:INFO:insert: Inserted fraxure
# root:INFO:insert: Inserted gible
# root:INFO:insert: Inserted dedenne
# root:INFO:insert: Inserted crobat
# root:INFO:insert: Inserted conkeldurr
# root:INFO:insert: Inserted glaceon
# root:INFO:insert: Inserted floette-red
# root:INFO:insert: Inserted crawdaunt
# root:INFO:insert: Inserted golisopod
# root:INFO:insert: Inserted exeggcute
# root:INFO:insert: Inserted glalie
# root:INFO:insert: Inserted flareon
# root:INFO:insert: Inserted exeggutor
# root:INFO:insert: Inserted claydol
# root:INFO:insert: Inserted chewtle
# root:INFO:insert: Inserted goomy
# root:INFO:insert: Inserted doublade
# root:INFO:insert: Inserted dracozolt
# root:INFO:insert: Inserted clobbopus
# root:INFO:insert: Inserted dwebble
# root:INFO:insert: Inserted fletchling
# root:INFO:insert: Inserted forretress
# root:INFO:insert: Inserted durant
# root:INFO:insert: Inserted dracovish
# root:INFO:insert: Inserted gallade
# root:INFO:insert: Inserted dugtrio
# root:INFO:insert: Inserted duraludon
# root:INFO:insert: Inserted dialga
# root:INFO:insert: Inserted chatot
# root:INFO:insert: Inserted deoxys-normal
# root:INFO:insert: Inserted geodude
# root:INFO:insert: Inserted gabite
# root:INFO:insert: Inserted musharna
# root:INFO:insert: Inserted mothim-plant
# root:INFO:insert: Inserted liepard
# root:INFO:insert: Inserted luvdisc
# root:INFO:insert: Inserted grapploct
# root:INFO:insert: Inserted krabby
# root:INFO:insert: Inserted helioptile
# root:INFO:insert: Inserted muk
# root:INFO:insert: Inserted magnemite
# root:INFO:insert: Inserted mienfoo
# root:INFO:insert: Inserted magcargo
# root:INFO:insert: Inserted lurantis
# root:INFO:insert: Inserted ledyba
# root:INFO:insert: Inserted grubbin
# root:INFO:insert: Inserted hawlucha
# root:INFO:insert: Inserted hippowdon
# root:INFO:insert: Inserted kirlia
# root:INFO:insert: Inserted hitmonlee
# root:INFO:insert: Inserted minccino
# root:INFO:insert: Inserted mewtwo
# root:INFO:insert: Inserted hattrem
# root:INFO:insert: Inserted misdreavus
# root:INFO:insert: Inserted kecleon
# root:INFO:insert: Inserted joltik
# root:INFO:insert: Inserted heracross
# root:INFO:insert: Inserted impidimp
# root:INFO:insert: Inserted lanturn
# root:INFO:insert: Inserted nickit
# root:INFO:insert: Inserted kubfu
# root:INFO:insert: Inserted mandibuzz
# root:INFO:insert: Inserted litten
# root:INFO:insert: Inserted mantine
# root:INFO:insert: Inserted mudbray
# root:INFO:insert: Inserted lunatone
# root:INFO:insert: Inserted moltres
# root:INFO:insert: Inserted lickilicky
# root:INFO:insert: Inserted minun
# root:INFO:insert: Inserted klinklang
# root:INFO:insert: Inserted houndour
# root:INFO:insert: Inserted minior-red-meteor
# root:INFO:insert: Inserted lugia
# root:INFO:insert: Inserted gurdurr
# root:INFO:insert: Inserted lickitung
# root:INFO:insert: Inserted lycanroc-midday
# root:INFO:insert: Inserted ho-oh
# root:INFO:insert: Inserted loudred
# root:INFO:insert: Inserted ledian
# root:INFO:insert: Inserted graveler
# root:INFO:insert: Inserted kricketune
# root:INFO:insert: Inserted guzzlord
# root:INFO:insert: Inserted lairon
# root:INFO:insert: Inserted mankey
# root:INFO:insert: Inserted klink
# root:INFO:insert: Inserted mareep
# root:INFO:insert: Inserted mudkip
# root:INFO:insert: Inserted litwick
# root:INFO:insert: Inserted jolteon
# root:INFO:insert: Inserted manectric
# root:INFO:insert: Inserted krookodile
# root:INFO:insert: Inserted kakuna
# root:INFO:insert: Inserted kabuto
# root:INFO:insert: Inserted jynx
# root:INFO:insert: Inserted growlithe
# root:INFO:insert: Inserted morpeko-full-belly
# root:INFO:insert: Inserted hydreigon
# root:INFO:insert: Inserted heatran
# root:INFO:insert: Inserted haunter
# root:INFO:insert: Inserted inteleon
# root:INFO:insert: Inserted magmar
# root:INFO:insert: Inserted machop
# root:INFO:insert: Inserted hatenna
# root:INFO:insert: Inserted jirachi
# root:INFO:insert: Inserted marshtomp
# root:INFO:insert: Inserted herdier
# root:INFO:insert: Inserted medicham
# root:INFO:insert: Inserted meowstic-male
# root:INFO:insert: Inserted lopunny
# root:INFO:insert: Inserted meditite
# root:INFO:insert: Inserted mime-jr
# root:INFO:insert: Inserted metagross
# root:INFO:insert: Inserted hariyama
# root:INFO:insert: Inserted happiny
# root:INFO:insert: Inserted igglybuff
# root:INFO:insert: Inserted mareanie
# root:INFO:insert: Inserted kricketot
# root:INFO:insert: Inserted hypno
# root:INFO:insert: Inserted lampent
# root:INFO:insert: Inserted indeedee-male
# root:INFO:insert: Inserted kyogre
# root:INFO:insert: Inserted magikarp
# root:INFO:insert: Inserted illumise
# root:INFO:insert: Inserted magearna
# root:INFO:insert: Inserted klang
# root:INFO:insert: Inserted marshadow
# root:INFO:insert: Inserted hitmonchan
# root:INFO:insert: Inserted marill
# root:INFO:insert: Inserted jigglypuff
# root:INFO:insert: Inserted hatterene
# root:INFO:insert: Inserted lilligant
# root:INFO:insert: Inserted lumineon
# root:INFO:insert: Inserted mawile
# root:INFO:insert: Inserted magnezone
# root:INFO:insert: Inserted mamoswine
# root:INFO:insert: Inserted hippopotas
# root:INFO:insert: Inserted honedge
# root:INFO:insert: Inserted gulpin
# root:INFO:insert: Inserted hoopa
# root:INFO:insert: Inserted lileep
# root:INFO:insert: Inserted mew
# root:INFO:insert: Inserted ivysaur
# root:INFO:insert: Inserted luxray
# root:INFO:insert: Inserted mienshao
# root:INFO:insert: Inserted lunala
# root:INFO:insert: Inserted metang
# root:INFO:insert: Inserted gumshoos
# root:INFO:insert: Inserted haxorus
# root:INFO:insert: Inserted karrablast
# root:INFO:insert: Inserted huntail
# root:INFO:insert: Inserted munna
# root:INFO:insert: Inserted jellicent
# root:INFO:insert: Inserted gyarados
# root:INFO:insert: Inserted mismagius
# root:INFO:insert: Inserted latias
# root:INFO:insert: Inserted makuhita
# root:INFO:insert: Inserted nidoqueen
# root:INFO:insert: Inserted grumpig
# root:INFO:insert: Inserted mesprit
# root:INFO:insert: Inserted heliolisk
# root:INFO:insert: Inserted klefki
# root:INFO:insert: Inserted linoone
# root:INFO:insert: Inserted keldeo-ordinary
# root:INFO:insert: Inserted lucario
# root:INFO:insert: Inserted grimer
# root:INFO:insert: Inserted hoothoot
# root:INFO:insert: Inserted naganadel
# root:INFO:insert: Inserted honchkrow
# root:INFO:insert: Inserted meowth
# root:INFO:insert: Inserted lombre
# root:INFO:insert: Inserted greninja
# root:INFO:insert: Inserted horsea
# root:INFO:insert: Inserted machoke
# root:INFO:insert: Inserted kyurem
# root:INFO:insert: Inserted grotle
# root:INFO:insert: Inserted larvitar
# root:INFO:insert: Inserted necrozma
# root:INFO:insert: Inserted houndoom
# root:INFO:insert: Inserted malamar
# root:INFO:insert: Inserted lotad
# root:INFO:insert: Inserted mightyena
# root:INFO:insert: Inserted mr-mime
# root:INFO:insert: Inserted luxio
# root:INFO:insert: Inserted meganium
# root:INFO:insert: Inserted milcery
# root:INFO:insert: Inserted metapod
# root:INFO:insert: Inserted grookey
# root:INFO:insert: Inserted landorus-incarnate
# root:INFO:insert: Inserted munchlax
# root:INFO:insert: Inserted meltan
# root:INFO:insert: Inserted jumpluff
# root:INFO:insert: Inserted kommo-o
# root:INFO:insert: Inserted leafeon
# root:INFO:insert: Inserted mr-rime
# root:INFO:insert: Inserted morelull
# root:INFO:insert: Inserted milotic
# root:INFO:insert: Inserted jangmo-o
# root:INFO:insert: Inserted maractus
# root:INFO:insert: Inserted kangaskhan
# root:INFO:insert: Inserted incineroar
# root:INFO:insert: Inserted murkrow
# root:INFO:insert: Inserted monferno
# root:INFO:insert: Inserted komala
# root:INFO:insert: Inserted leavanny
# root:INFO:insert: Inserted kingler
# root:INFO:insert: Inserted miltank
# root:INFO:insert: Inserted krokorok
# root:INFO:insert: Inserted koffing
# root:INFO:insert: Inserted latios
# root:INFO:insert: Inserted inkay
# root:INFO:insert: Inserted kadabra
# root:INFO:insert: Inserted kingdra
# root:INFO:insert: Inserted kabutops
# root:INFO:insert: Inserted infernape
# root:INFO:insert: Inserted natu
# root:INFO:insert: Inserted mantyke
# root:INFO:insert: Inserted mimikyu-disguised
# root:INFO:insert: Inserted magmortar
# root:INFO:insert: Inserted grimmsnarl
# root:INFO:insert: Inserted larvesta
# root:INFO:insert: Inserted machamp
# root:INFO:insert: Inserted meloetta-aria
# root:INFO:insert: Inserted mudsdale
# root:INFO:insert: Inserted morgrem
# root:INFO:insert: Inserted hoppip
# root:INFO:insert: Inserted nidoking
# root:INFO:insert: Inserted hakamo-o
# root:INFO:insert: Inserted melmetal
# root:INFO:insert: Inserted manaphy
# root:INFO:insert: Inserted magby
# root:INFO:insert: Inserted groudon
# root:INFO:insert: Inserted lapras
# root:INFO:insert: Inserted hitmontop
# root:INFO:insert: Inserted grovyle
# root:INFO:insert: Inserted marowak
# root:INFO:insert: Inserted greedent
# root:INFO:insert: Inserted heatmor
# root:INFO:insert: Inserted masquerain
# root:INFO:insert: Inserted litleo
# root:INFO:insert: Inserted magneton
# root:INFO:insert: Inserted ludicolo
# root:INFO:insert: Inserted kartana
# root:INFO:insert: Inserted lillipup
# root:INFO:insert: Inserted regigigas
# root:INFO:insert: Inserted noctowl
# root:INFO:insert: Inserted scatterbug-icy-snow
# root:INFO:insert: Inserted prinplup
# root:INFO:insert: Inserted petilil
# root:INFO:insert: Inserted pincurchin
# root:INFO:insert: Inserted pawniard
# root:INFO:insert: Inserted ralts
# root:INFO:insert: Inserted sandslash
# root:INFO:insert: Inserted sandaconda
# root:INFO:insert: Inserted runerigus
# root:INFO:insert: Inserted porygon-z
# root:INFO:insert: Inserted pyukumuku
# root:INFO:insert: Inserted rhyperior
# root:INFO:insert: Inserted simisear
# root:INFO:insert: Inserted noivern
# root:INFO:insert: Inserted simisage
# root:INFO:insert: Inserted skrelp
# root:INFO:insert: Inserted slowbro
# root:INFO:insert: Inserted salazzle
# root:INFO:insert: Inserted nidoran-f
# root:INFO:insert: Inserted sneasel
# root:INFO:insert: Inserted plusle
# root:INFO:insert: Inserted ninjask
# root:INFO:insert: Inserted smoochum
# root:INFO:insert: Inserted shinx
# root:INFO:insert: Inserted pumpkaboo-average
# root:INFO:insert: Inserted slowpoke
# root:INFO:insert: Inserted poipole
# root:INFO:insert: Inserted skuntank
# root:INFO:insert: Inserted reuniclus
# root:INFO:insert: Inserted sharpedo
# root:INFO:insert: Inserted shellos-west
# root:INFO:insert: Inserted samurott
# root:INFO:insert: Inserted pelipper
# root:INFO:insert: Inserted sawk
# root:INFO:insert: Inserted parasect
# root:INFO:insert: Inserted sceptile
# root:INFO:insert: Inserted omanyte
# root:INFO:insert: Inserted sewaddle
# root:INFO:insert: Inserted purrloin
# root:INFO:insert: Inserted slakoth
# root:INFO:insert: Inserted nihilego
# root:INFO:insert: Inserted shelgon
# root:INFO:insert: Inserted poochyena
# root:INFO:insert: Inserted roselia
# root:INFO:insert: Inserted psyduck
# root:INFO:insert: Inserted quilava
# root:INFO:insert: Inserted silicobra
# root:INFO:insert: Inserted silvally-normal
# root:INFO:insert: Inserted scorbunny
# root:INFO:insert: Inserted skitty
# root:INFO:insert: Inserted rattata
# root:INFO:insert: Inserted relicanth
# root:INFO:insert: Inserted numel
# root:INFO:insert: Inserted rufflet
# root:INFO:insert: Inserted rockruff
# root:INFO:insert: Inserted shuppet
# root:INFO:insert: Inserted smeargle
# root:INFO:insert: Inserted seviper
# root:INFO:insert: Inserted sigilyph
# root:INFO:insert: Inserted sinistea-phony
# root:INFO:insert: Inserted palpitoad
# root:INFO:insert: Inserted raichu
# root:INFO:insert: Inserted pansage
# root:INFO:insert: Inserted rookidee
# root:INFO:insert: Inserted shiinotic
# root:INFO:insert: Inserted pikipek
# root:INFO:insert: Inserted palkia
# root:INFO:insert: Inserted scolipede
# root:INFO:insert: Inserted salamence
# root:INFO:insert: Inserted rowlet
# root:INFO:insert: Inserted pheromosa
# root:INFO:insert: Inserted polteageist-phony
# root:INFO:insert: Inserted piplup
# root:INFO:insert: Inserted persian
# root:INFO:insert: Inserted nidoran-m
# root:INFO:insert: Inserted qwilfish
# root:INFO:insert: Inserted slaking
# root:INFO:insert: Inserted simipour
# root:INFO:insert: Inserted seaking
# root:INFO:insert: Inserted poliwag
# root:INFO:insert: Inserted riolu
# root:INFO:insert: Inserted patrat
# root:INFO:insert: Inserted snom
# root:INFO:insert: Inserted passimian
# root:INFO:insert: Inserted regice
# root:INFO:insert: Inserted rillaboom
# root:INFO:insert: Inserted snorlax
# root:INFO:insert: Inserted skiploom
# root:INFO:insert: Inserted phantump
# root:INFO:insert: Inserted panpour
# root:INFO:insert: Inserted nuzleaf
# root:INFO:insert: Inserted salandit
# root:INFO:insert: Inserted shuckle
# root:INFO:insert: Inserted quagsire
# root:INFO:insert: Inserted regieleki
# root:INFO:insert: Inserted scrafty
# root:INFO:insert: Inserted sentret
# root:INFO:insert: Inserted serperior
# root:INFO:insert: Inserted oshawott
# root:INFO:insert: Inserted rhydon
# root:INFO:insert: Inserted rayquaza
# root:INFO:insert: Inserted shieldon
# root:INFO:insert: Inserted popplio
# root:INFO:insert: Inserted onix
# root:INFO:insert: Inserted sandile
# root:INFO:insert: Inserted purugly
# root:INFO:insert: Inserted slurpuff
# root:INFO:insert: Inserted reshiram
# root:INFO:insert: Inserted regirock
# root:INFO:insert: Inserted probopass
# root:INFO:insert: Inserted slowking
# root:INFO:insert: Inserted shiftry
# root:INFO:insert: Inserted scyther
# root:INFO:insert: Inserted octillery
# root:INFO:insert: Inserted sandygast
# root:INFO:insert: Inserted sealeo
# root:INFO:insert: Inserted sawsbuck-spring
# root:INFO:insert: Inserted shaymin-land
# root:INFO:insert: Inserted servine
# root:INFO:insert: Inserted slugma
# root:INFO:insert: Inserted skorupi
# root:INFO:insert: Inserted snover
# root:INFO:insert: Inserted rotom
# root:INFO:insert: Inserted poliwrath
# root:INFO:insert: Inserted porygon2
# root:INFO:insert: Inserted obstagoon
# root:INFO:insert: Inserted pidgeot
# root:INFO:insert: Inserted seedot
# root:INFO:insert: Inserted primeape
# root:INFO:insert: Inserted snivy
# root:INFO:insert: Inserted scizor
# root:INFO:insert: Inserted sirfetchd
# root:INFO:insert: Inserted snorunt
# root:INFO:insert: Inserted raboot
# root:INFO:insert: Inserted quilladin
# root:INFO:insert: Inserted seismitoad
# root:INFO:insert: Inserted perrserker
# root:INFO:insert: Inserted palossand
# root:INFO:insert: Inserted skiddo
# root:INFO:insert: Inserted scraggy
# root:INFO:insert: Inserted rampardos
# root:INFO:insert: Inserted pangoro
# root:INFO:insert: Inserted silcoon
# root:INFO:insert: Inserted pachirisu
# root:INFO:insert: Inserted sandshrew
# root:INFO:insert: Inserted porygon
# root:INFO:insert: Inserted regidrago
# root:INFO:insert: Inserted oricorio-baile
# root:INFO:insert: Inserted sizzlipede
# root:INFO:insert: Inserted phione
# root:INFO:insert: Inserted skwovet
# root:INFO:insert: Inserted nidorino
# root:INFO:insert: Inserted oddish
# root:INFO:insert: Inserted noibat
# root:INFO:insert: Inserted roggenrola
# root:INFO:insert: Inserted seel
# root:INFO:insert: Inserted nosepass
# root:INFO:insert: Inserted ninetales
# root:INFO:insert: Inserted shroomish
# root:INFO:insert: Inserted seadra
# root:INFO:insert: Inserted registeel
# root:INFO:insert: Inserted poliwhirl
# root:INFO:insert: Inserted shellder
# root:INFO:insert: Inserted pansear
# root:INFO:insert: Inserted oranguru
# root:INFO:insert: Inserted skarmory
# root:INFO:insert: Inserted piloswine
# root:INFO:insert: Inserted pichu
# root:INFO:insert: Inserted nincada
# root:INFO:insert: Inserted pyroar
# root:INFO:insert: Inserted nidorina
# root:INFO:insert: Inserted pidgeotto
# root:INFO:insert: Inserted raikou
# root:INFO:insert: Inserted phanpy
# root:INFO:insert: Inserted ribombee
# root:INFO:insert: Inserted pineco
# root:INFO:insert: Inserted raticate
# root:INFO:insert: Inserted paras
# root:INFO:insert: Inserted ponyta
# root:INFO:insert: Inserted orbeetle
# root:INFO:insert: Inserted pupitar
# root:INFO:insert: Inserted omastar
# root:INFO:insert: Inserted primarina
# root:INFO:insert: Inserted pancham
# root:INFO:insert: Inserted shelmet
# root:INFO:insert: Inserted pidgey
# root:INFO:insert: Inserted rapidash
# root:INFO:insert: Inserted pinsir
# root:INFO:insert: Inserted sliggoo
# root:INFO:insert: Inserted roserade
# root:INFO:insert: Inserted politoed
# root:INFO:insert: Inserted rhyhorn
# root:INFO:insert: Inserted rolycoly
# root:INFO:insert: Inserted sableye
# root:INFO:insert: Inserted remoraid
# root:INFO:insert: Inserted pignite
# root:INFO:insert: Inserted pikachu
# root:INFO:insert: Inserted shedinja
# root:INFO:insert: Inserted pidove
# root:INFO:insert: Inserted spiritomb
# root:INFO:insert: Inserted vivillon-meadow
# root:INFO:insert: Inserted swanna
# root:INFO:insert: Inserted torracat
# root:INFO:insert: Inserted zubat
# root:INFO:insert: Inserted throh
# root:INFO:insert: Inserted teddiursa
# root:INFO:insert: Inserted wooper
# root:INFO:insert: Inserted wynaut
# root:INFO:insert: Inserted tsareena
# root:INFO:insert: Inserted type-null
# root:INFO:insert: Inserted surskit
# root:INFO:insert: Inserted yanma
# root:INFO:insert: Inserted wormadam-plant
# root:INFO:insert: Inserted whimsicott
# root:INFO:insert: Inserted stunfisk
# root:INFO:insert: Inserted umbreon
# root:INFO:insert: Inserted yveltal
# root:INFO:insert: Inserted whirlipede
# root:INFO:insert: Inserted staravia
# root:INFO:insert: Inserted unfezant
# root:INFO:insert: Inserted yanmega
# root:INFO:insert: Inserted swirlix
# root:INFO:insert: Inserted trubbish
# root:INFO:insert: Inserted vigoroth
# root:INFO:insert: Inserted spectrier
# root:INFO:insert: Inserted zacian-hero
# root:INFO:insert: Inserted zangoose
# root:INFO:insert: Inserted trumbeak
# root:INFO:insert: Inserted swampert
# root:INFO:insert: Inserted weezing
# root:INFO:insert: Inserted turtwig
# root:INFO:insert: Inserted weedle
# root:INFO:insert: Inserted venonat
# root:INFO:insert: Inserted spoink
# root:INFO:insert: Inserted trapinch
# root:INFO:insert: Inserted swalot
# root:INFO:insert: Inserted suicune
# root:INFO:insert: Inserted unown-a
# root:INFO:insert: Inserted stakataka
# root:INFO:insert: Inserted swinub
# root:INFO:insert: Inserted sunkern
# root:INFO:insert: Inserted wingull
# root:INFO:insert: Inserted watchog
# root:INFO:insert: Inserted zamazenta-hero
# root:INFO:insert: Inserted spritzee
# root:INFO:insert: Inserted tentacruel
# root:INFO:insert: Inserted victreebel
# root:INFO:insert: Inserted weavile
# root:INFO:insert: Inserted tyrunt
# root:INFO:insert: Inserted swoobat
# root:INFO:insert: Inserted zarude
# root:INFO:insert: Inserted vanillite
# root:INFO:insert: Inserted tranquill
# root:INFO:insert: Inserted uxie
# root:INFO:insert: Inserted togepi
# root:INFO:insert: Inserted xurkitree
# root:INFO:insert: Inserted venusaur
# root:INFO:insert: Inserted yungoos
# root:INFO:insert: Inserted tepig
# root:INFO:insert: Inserted tropius
# root:INFO:insert: Inserted yamask
# root:INFO:insert: Inserted spinda
# root:INFO:insert: Inserted stunky
# root:INFO:insert: Inserted sudowoodo
# root:INFO:insert: Inserted zekrom
# root:INFO:insert: Inserted totodile
# root:INFO:insert: Inserted weepinbell
# root:INFO:insert: Inserted wartortle
# root:INFO:insert: Inserted swellow
# root:INFO:insert: Inserted vulpix
# root:INFO:insert: Inserted solgaleo
# root:INFO:insert: Inserted zweilous
# root:INFO:insert: Inserted togedemaru
# root:INFO:insert: Inserted toxicroak
# root:INFO:insert: Inserted spearow
# root:INFO:insert: Inserted turtonator
# root:INFO:insert: Inserted vespiquen
# root:INFO:insert: Inserted tauros
# root:INFO:insert: Inserted woobat
# root:INFO:insert: Inserted terrakion
# root:INFO:insert: Inserted treecko
# root:INFO:insert: Inserted stantler
# root:INFO:insert: Inserted wobbuffet
# root:INFO:insert: Inserted tapu-bulu
# root:INFO:insert: Inserted wigglytuff
# root:INFO:insert: Inserted trevenant
# root:INFO:insert: Inserted walrein
# root:INFO:insert: Inserted wimpod
# root:INFO:insert: Inserted zebstrika
# root:INFO:insert: Inserted virizion
# root:INFO:insert: Inserted tyrogue
# root:INFO:insert: Inserted typhlosion
# root:INFO:insert: Inserted togetic
# root:INFO:insert: Inserted tapu-lele
# root:INFO:insert: Inserted zapdos
# root:INFO:insert: Inserted tornadus-incarnate
# root:INFO:insert: Inserted timburr
# root:INFO:insert: Inserted tympole
# root:INFO:insert: Inserted sylveon
# root:INFO:insert: Inserted voltorb
# root:INFO:insert: Inserted tangela
# root:INFO:insert: Inserted xatu
# root:INFO:insert: Inserted vanillish
# root:INFO:insert: Inserted vanilluxe
# root:INFO:insert: Inserted solrock
# root:INFO:insert: Inserted taillow
# root:INFO:insert: Inserted wooloo
# root:INFO:insert: Inserted tapu-koko
# root:INFO:insert: Inserted wurmple
# root:INFO:insert: Inserted stoutland
# root:INFO:insert: Inserted thievul
# root:INFO:insert: Inserted zorua
# root:INFO:insert: Inserted stonjourner
# root:INFO:insert: Inserted steelix
# root:INFO:insert: Inserted tynamo
# root:INFO:insert: Inserted thundurus-incarnate
# root:INFO:insert: Inserted venipede
# root:INFO:insert: Inserted steenee
# root:INFO:insert: Inserted togekiss
# root:INFO:insert: Inserted tyrantrum
# root:INFO:insert: Inserted toxapex
# root:INFO:insert: Inserted wailmer
# root:INFO:insert: Inserted staryu
# root:INFO:insert: Inserted victini
# root:INFO:insert: Inserted vibrava
# root:INFO:insert: Inserted snubbull
# root:INFO:insert: Inserted zigzagoon
# root:INFO:insert: Inserted spinarak
# root:INFO:insert: Inserted wishiwashi-solo
# root:INFO:insert: Inserted torkoal
# root:INFO:insert: Inserted ursaring
# root:INFO:insert: Inserted yamper
# root:INFO:insert: Inserted vullaby
# root:INFO:insert: Inserted zeraora
# root:INFO:insert: Inserted tyranitar
# root:INFO:insert: Inserted starmie
# root:INFO:insert: Inserted thwackey
# root:INFO:insert: Inserted zygarde
# root:INFO:insert: Inserted vikavolt
# root:INFO:insert: Inserted stufful
# root:INFO:insert: Inserted xerneas-active
# root:INFO:insert: Inserted whiscash
# root:INFO:insert: Inserted toxel
# root:INFO:insert: Inserted spewpa-icy-snow
# root:INFO:insert: Inserted tangrowth
# root:INFO:insert: Inserted vileplume
# root:INFO:insert: Inserted whismur
# root:INFO:insert: Inserted talonflame
# root:INFO:insert: Inserted wailord
# root:INFO:insert: Inserted spheal
# root:INFO:insert: Inserted volcarona
# root:INFO:insert: Inserted tirtouga
# root:INFO:insert: Inserted starly
# root:INFO:insert: Inserted torchic
# root:INFO:insert: Inserted toucannon
# root:INFO:insert: Inserted tentacool
# root:INFO:insert: Inserted zoroark
# root:INFO:insert: Inserted urshifu-single-strike
# root:INFO:insert: Inserted toxtricity-amped
# root:INFO:insert: Inserted torterra
# root:INFO:insert: Inserted venomoth
# root:INFO:insert: Inserted tapu-fini
# root:INFO:insert: Inserted sobble
# root:INFO:insert: Inserted swadloon
# root:INFO:insert: Inserted squirtle
# root:INFO:insert: Inserted volbeat
# root:INFO:insert: Inserted swablu
# root:INFO:insert: Inserted vaporeon
# root:INFO:insert: Inserted sunflora
# root:INFO:insert: Inserted staraptor
# root:INFO:insert: Inserted solosis
# root:INFO:insert: Inserted volcanion

# %%
db.backend.env.stat()['entries']
# Out:
# 898

# %%
reload(logging)
logging.basicConfig(
    format='%(name)s:%(levelname)s:%(funcName)s: %(message)s',
    level=logging.DEBUG
)
db.search('a round pink ball with two blue eyes')
# Out:
# root:DEBUG:read_node: Got serialized Node: b'\x80\x04\x95@\x14\x00\x00\x00\x00\x00\x00\x8c\x08__main__\x94\x8c\x04Node\x94\x93\x94)\x81\x94}\x94(\x8c\x02id\x94\x8c\x14basculin-red-striped\x94\x8c\tembedding\x94\x8c\x0ctorch._utils\x94\x8c\x12_rebuild_tensor_v2\x94\x93\x94(\x8c\rtorch.storage\x94\x8c\x10_load_from_bytes\x94\x93\x94B\xfe\x08\x00\x00\x80\x02\x8a\nl\xfc\x9cF\xf9 j\xa8P\x19.\x80\x02M\xe9\x03.\x80\x02}q\x00(X\x10\x00\x00\x00protocol_versionq\x01M\xe9\x03X\r\x00\x00\x00little_endianq\x02\x88X\n\x00\x00\x00type_sizesq\x03}q\x04(X\x05\x00\x00\x00shortq\x05K\x02X\x03\x00\x00\x00intq\x06K\x04X\x04\x00\x00\x00longq\x07K\x04uu.\x80\x02(X\x07\x00\x00\x00storageq\x00ctorch\nFloatStorage\nq\x01X\x0f\x00\x00\x00101295651840016q\x02X\x03\x00\x00\x00cpuq\x03M\x00\x02Ntq\x04Q.\x80\x02]q\x00X\x0f\x00\x00\x00101295651840016q\x01a.\x00\x02\x00\x00\x00\x00\x00\x00\xa1@\x0e?\xbd\xd0\xbc\xbd\xde\xc6\xc8\xbd\x91*\x9d\xbe\x9f\xed\x13?\x81\xd1\x8f\xbe\x1e\xf0\x1f\xbef\x14!?i\xbd\x0f?\xf0\xde_\xbb\xd7\x040?\xa9,\xef\xbdMX\x88>\x84\xd0.\xbf\xf3?,>\xe7\xe0+\xbd&>\xf4>7\xe9\\?\xe1/3\xbe\xf9\xf2\xaf\xbe}\x1d\xdf\xbe\xed\xf4\xe6\xbe\x19\xc3\xf5=\x91O\x9f<\xbd\xb1\xb4\xbe\xa5\xb6\xa7=\x02\xda\x03>5\x86p\xbej\xe8\x8e\xbd\xf6F\xd2=T\xb6@=\xf5\xe5$\xbc\x81\xf9\xe2>I\x1b\x1a=B:H>0<C\xbe\xb1\x16\x7f\xbex"\xd5>\x9c?\x13?\x14\xfa\xe6\xbbJ\x9c\xa3\xbe\r,\x17\xbe\x9f\xd3X\xbd<\x0c\xef\xbdWG\x95>\xcb\x15\xca?T\xca(\xbe%\x88\xb8>Oa\x93\xbdX\xb9n\xbd\x87\x0eO\xbex\x0e\x1a\xbem\x10`>S\xd1d\xbe\xeb\xe5\x08>\xf7\x10\xca=B=)>\x15\x91\'\xbe\xe9\xd9\xd4=\x
# root:DEBUG:bfs_with_max_heap: priorities found by bfs [21.55]
# root:DEBUG:search_embedding: Traversed 222 during search
# (hatterene, 21.550989151000977)

# %%
# TODO: brute force search to evaluate how effective CLIP actually is
image = get_image_from_url(url)
image_embeddings = get_embedding_from_image(image, processor, model)


texts = ['a round pink ball with two blue eyes']
text_input = processor(text=texts, return_tensors="pt", padding=True)

with torch.no_grad():
  text_embeddings = model.get_text_features(**text_input)

image_embeddings = [n.embedding for n in db.layers[0]]
stacked_tensors = torch.stack([i.embedding for i in db.layers[0]])
dot_products = torch.sum(text_embeddings * stacked_tensors, dim=-1).tolist()

# %%
ind = np.argmax(dot_products)
dot_products[ind]
# Out:
# 24.322616577148438

# %%
db.layers[0][ind]
# Out:
# voltorb

# %%
# count of members per layer
for k, v in db.layers.items():
  print(f'{k}: {len(v)} ({v})')
# Out:
# 0: 899 ([pikachu, bergmite, barboach, alakazam, azelf, axew, braixen, celebi, carracosta, arceus-normal, chandelure, blacephalon, braviary, arrokuda, banette, arbok, butterfree, blaziken, bouffalant, burmy-plant, aromatisse, araquanid, articuno, charmander, binacle, carbink, charjabug, abomasnow, armaldo, castform, calyrex, aerodactyl, bastiodon, brionne, altaria, blipbug, arcanine, boltund, celesteela, centiskorch, cascoon, bellsprout, accelgor, bayleef, basculin-red-striped, bagon, beedrill, bonsly, arctovish, alomomola, aron, bellossom, charizard, breloom, blastoise, aurorus, blitzle, buneary, blissey, beldum, archen, amoonguss, absol, boldore, beautifly, carvanha, bruxish, bisharp, bewear, camerupt, abra, bronzor, cacnea, audino, barraskewda, bounsweet, arctozolt, amaura, bibarel, carnivine, barbaracle, avalugg, aipom, buizel, beartic, beheeyem, alcremie, bidoof, azumarill, azurill, caterpie, ampharos, bulbasaur, buzzwole, baltoy, chansey, anorith, carkol, archeops, applin, cacturne, aggron, appletun, ariados, budew, aegislash-shield, ambipom, bunnelby, bronzong, eevee, feebas, fletchinder, cosmog, coalossal, dusknoir, clefable, chikorita, darkrai, dhelmise, clefairy, drednaw, empoleon, cresselia, clamperl, drakloak, darumaka, drowzee, cinderace, dragonair, flapple, delibird, dunsparce, gligar, chimecho, golbat, dragalge, garchomp, deino, garbodor, gastly, dusclops, goodra, combee, espurr, eelektross, fearow, cranidos, gothorita, crabominable, giratina-altered, foongus, corvisquire, comfey, goldeen, golduck, eiscue-ice, eternatus, flabebe-red, copperajah, electabuzz, cradily, electivire, ditto, dottler, excadrill, gliscor, cofagrigus, dodrio, glastrier, floatzel, galvantula, gourgeist-average, furfrou-natural, clawitzer, ducklett, chingling, flaaffy, gardevoir, clauncher, dragapult, drilbur, druddigon, decidueye, cherrim-overcast, golem, espeon, frillish, duosion, gengar, ferroseed, drapion, corsola, golett, chimchar, cryogonal, dreepy, falinks, delcatty, cubchoo, cubone, dewgong, combusken, gogoat, electrike, elekid, dratini, croconaw, gigalith, dartrix, frosmoth, granbull, fomantis, cloyster, chinchou, farfetchd, cleffa, croagunk, flygon, cottonee, escavalier, genesect, doduo, fennekin, deerling-spring, drifloon, donphan, diancie, cobalion, eldegoss, frogadier, cyndaquil, crustle, cosmoem, chespin, gastrodon-west, drampa, girafarig, duskull, emboar, glameow, entei, ekans, froakie, ferrothorn, cufant, dewpider, dewott, dubwool, elgyem, drizzile, exploud, furret, drifblim, delphox, gothitelle, cinccino, gloom, diggersby, froslass, cursola, cherubi, gothita, darmanitan-standard, florges-red, finneon, gorebyss, dustox, gossifleur, corphish, cutiefly, feraligatr, eelektrik, chesnaught, cramorant, corviknight, electrode, golurk, dragonite, crabrawler, emolga, charmeleon, diglett, fraxure, gible, dedenne, crobat, conkeldurr, glaceon, floette-red, crawdaunt, golisopod, exeggcute, glalie, flareon, exeggutor, claydol, chewtle, goomy, doublade, dracozolt, clobbopus, dwebble, fletchling, forretress, durant, dracovish, gallade, dugtrio, duraludon, dialga, chatot, deoxys-normal, geodude, gabite, musharna, mothim-plant, liepard, luvdisc, grapploct, krabby, helioptile, muk, magnemite, mienfoo, magcargo, lurantis, ledyba, grubbin, hawlucha, hippowdon, kirlia, hitmonlee, minccino, mewtwo, hattrem, misdreavus, kecleon, joltik, heracross, impidimp, lanturn, nickit, kubfu, mandibuzz, litten, mantine, mudbray, lunatone, moltres, lickilicky, minun, klinklang, houndour, minior-red-meteor, lugia, gurdurr, lickitung, lycanroc-midday, ho-oh, loudred, ledian, graveler, kricketune, guzzlord, lairon, mankey, klink, mareep, mudkip, litwick, jolteon, manectric, krookodile, kakuna, kabuto, jynx, growlithe, morpeko-full-belly, hydreigon, heatran, haunter, inteleon, magmar, machop, hatenna, jirachi, marshtomp, herdier, medicham, meowstic-male, lopunny, meditite, mime-jr, metagross, hariyama, happiny, igglybuff, mareanie, kricketot, hypno, lampent, indeede ...
# 1: 90 ([pikachu, bergmite, chandelure, brionne, blipbug, blissey, ampharos, bulbasaur, applin, bronzong, cosmog, drakloak, eelektross, foongus, golduck, eiscue-ice, ducklett, flaaffy, decidueye, golem, elekid, frosmoth, fomantis, cobalion, froakie, delphox, gloom, gothita, darmanitan-standard, dustox, feraligatr, eelektrik, glalie, claydol, dugtrio, grapploct, kirlia, impidimp, klink, kakuna, jynx, magikarp, lilligant, gulpin, luxray, mienshao, huntail, jellicent, lotad, morelull, milotic, magmortar, nidoking, magby, masquerain, lillipup, petilil, porygon-z, shinx, roselia, rowlet, rillaboom, rayquaza, onix, servine, skwovet, oddish, noibat, seadra, skarmory, pichu, phanpy, politoed, rhyhorn, pignite, type-null, yanma, suicune, swinub, tepig, spinda, stantler, togetic, tornadus-incarnate, voltorb, zigzagoon, wishiwashi-solo, stufful, wailord, torchic])
# 2: 10 ([pikachu, eiscue-ice, frosmoth, froakie, eelektrik, lilligant, mienshao, rowlet, politoed, type-null])
# 3: 2 ([pikachu, mienshao])

# %%
# in one layer, how many edges exist between members
for i in db.layers[1]:
  print(i.id, len(i.get_edges(1)))
# Out:
# pikachu 4
# azelf 4
# braixen 4
# carracosta 4
# arceus-normal 4

# %%
node.get_edges(0)
# Out:
# []

# %%
reload(logging)
logging.basicConfig(
    format='%(name)s:%(levelname)s:%(funcName)s: %(message)s',
    level=logging.DEBUG
)
db.insert(node, 3)
# Out:
# root:DEBUG:insert: Determined insertion_layer: 3
# root:DEBUG:insert: P2: current_layer: 3
# root:DEBUG:bfs_with_max_heap: Starting bfs on layer 3 with 1 start nodes: ['pikachu'], ef 10...
# root:DEBUG:bfs_with_max_heap: 	Got 0 unexplored neighbors from node pikachu: []
# root:DEBUG:insert: P2: Got 1 candidate nodes
# root:DEBUG:insert: P2 Adding edge to pikachu
# root:DEBUG:add_edge: adding pikachu to braviary in layer 3
# root:DEBUG:add_edge: adding braviary to pikachu in layer 3
# root:DEBUG:insert: P2: current_layer: 2
# root:DEBUG:bfs_with_max_heap: Starting bfs on layer 2 with 1 start nodes: ['pikachu'], ef 10...
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node pikachu: ['azelf']
# root:DEBUG:bfs_with_max_heap: 	Got 0 unexplored neighbors from node azelf: []
# root:DEBUG:insert: P2: Got 2 candidate nodes
# root:DEBUG:insert: P2 Adding edge to pikachu
# root:DEBUG:add_edge: adding pikachu to braviary in layer 2
# root:DEBUG:add_edge: adding braviary to pikachu in layer 2
# root:DEBUG:insert: P2 Adding edge to azelf
# root:DEBUG:add_edge: adding azelf to braviary in layer 2
# root:DEBUG:add_edge: adding braviary to azelf in layer 2
# root:DEBUG:insert: P2: current_layer: 1
# root:DEBUG:bfs_with_max_heap: Starting bfs on layer 1 with 2 start nodes: ['azelf', 'pikachu'], ef 10...
# root:DEBUG:bfs_with_max_heap: 	Got 3 unexplored neighbors from node azelf: ['carracosta', 'braixen', 'arceus-normal']
# root:DEBUG:bfs_with_max_heap: 	Got 0 unexplored neighbors from node pikachu: []
# root:DEBUG:bfs_with_max_heap: 	Got 0 unexplored neighbors from node carracosta: []
# root:DEBUG:bfs_with_max_heap: 	Got 0 unexplored neighbors from node braixen: []
# root:DEBUG:bfs_with_max_heap: 	Got 0 unexplored neighbors from node arceus-normal: []
# root:DEBUG:insert: P2: Got 5 candidate nodes
# root:DEBUG:insert: P2 Adding edge to braixen
# root:DEBUG:add_edge: adding braixen to braviary in layer 1
# root:DEBUG:add_edge: adding braviary to braixen in layer 1
# root:DEBUG:insert: P2 Adding edge to arceus-normal
# root:DEBUG:add_edge: adding arceus-normal to braviary in layer 1
# root:DEBUG:add_edge: adding braviary to arceus-normal in layer 1
# root:DEBUG:insert: P2 Adding edge to pikachu
# root:DEBUG:add_edge: adding pikachu to braviary in layer 1
# root:DEBUG:add_edge: adding braviary to pikachu in layer 1
# root:DEBUG:insert: P2 Adding edge to azelf
# root:DEBUG:add_edge: adding azelf to braviary in layer 1
# root:DEBUG:add_edge: adding braviary to azelf in layer 1
# root:DEBUG:insert: P2 Adding edge to carracosta
# root:DEBUG:add_edge: adding carracosta to braviary in layer 1
# root:DEBUG:add_edge: adding braviary to carracosta in layer 1
# root:DEBUG:insert: P2: current_layer: 0
# root:DEBUG:bfs_with_max_heap: Starting bfs on layer 0 with 5 start nodes: ['carracosta', 'azelf', 'pikachu', 'arceus-normal', 'braixen'], ef 10...
# root:DEBUG:bfs_with_max_heap: 	Got 6 unexplored neighbors from node carracosta: ['alakazam', 'axew', 'bergmite', 'celebi', 'barboach', 'chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node azelf: ['chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node pikachu: ['chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node arceus-normal: ['chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node braixen: ['chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node alakazam: ['chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node axew: ['chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node bergmite: ['chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node celebi: ['chandelure']
# root:DEBUG:bfs_with_max_heap: 	Got 1 unexplored neighbors from node barboach: ['chandelure']
# root:DEBUG:insert: P2: Got 10 candidate nodes
# root:DEBUG:insert: P2 Adding edge to axew
# root:DEBUG:add_edge: adding axew to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to axew in layer 0
# root:DEBUG:insert: P2 Adding edge to braixen
# root:DEBUG:add_edge: adding braixen to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to braixen in layer 0
# root:DEBUG:insert: P2 Adding edge to barboach
# root:DEBUG:add_edge: adding barboach to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to barboach in layer 0
# root:DEBUG:insert: P2 Adding edge to celebi
# root:DEBUG:add_edge: adding celebi to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to celebi in layer 0
# root:DEBUG:insert: P2 Adding edge to arceus-normal
# root:DEBUG:add_edge: adding arceus-normal to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to arceus-normal in layer 0
# root:DEBUG:insert: P2 Adding edge to pikachu
# root:DEBUG:add_edge: adding pikachu to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to pikachu in layer 0
# root:DEBUG:insert: P2 Adding edge to azelf
# root:DEBUG:add_edge: adding azelf to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to azelf in layer 0
# root:DEBUG:insert: P2 Adding edge to alakazam
# root:DEBUG:add_edge: adding alakazam to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to alakazam in layer 0
# root:DEBUG:insert: P2 Adding edge to carracosta
# root:DEBUG:add_edge: adding carracosta to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to carracosta in layer 0
# root:DEBUG:insert: P2 Adding edge to bergmite
# root:DEBUG:add_edge: adding bergmite to braviary in layer 0
# root:DEBUG:add_edge: adding braviary to bergmite in layer 0

# %%
db.layers[3][0].get_edges(3)
# Out:
# [braviary]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0356b5092fc3> in <cell line: 2>()
#       1 # TODO: implement persistence and move embedding storage out of RAM
# ----> 2 import lmdb
#       3 import pickle
#       4
#       5 # Example Node class
#
# ModuleNotFoundError: No module named 'lmdb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
